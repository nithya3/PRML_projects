# %%
import numpy as np
import pandas as pd
import lightgbm as lgb
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import f1_score, accuracy_score, balanced_accuracy_score

# %%
train = pd.read_csv("Train_added_features_final.csv", index_col=0)
test = pd.read_csv("Test_added_features_final.csv", index_col=0)

# %%
train.head()
# Out:
#         comp  left  Reused_id  1_ratings  2_ratings  3_ratings  4_ratings  \
# id
# 0   0.066176     0        0.0   0.250000   0.250000   0.250000   0.250000
# 4   0.066176     0        0.0   0.000000   0.136364   0.272727   0.590909
# 6   0.066176     0        0.0   0.015385   0.025641   0.046154   0.912821
# 7   0.066176     0        0.0   0.137931   0.172414   0.448276   0.241379
# 8   0.066176     1        1.0   0.066667   0.200000   0.600000   0.133333
#
#     total_num_ratings  lastrating  Delta_days  ...  2_reviews_opposed  \
# id                                             ...
# 0                 4.0           4         283  ...           0.250000
# 4                22.0           4          92  ...           0.000000
# 6               195.0           4           0  ...           0.083333
# 7                29.0           4           0  ...           0.000000
# 8                15.0           3           2  ...           0.083333
#
#     3_reviews_supported  3_reviews_opposed  4_reviews_supported  \
# id
# 0              0.250000           0.250000             0.250000
# 4              0.000000           0.500000             0.666667
# 6              0.212121           0.333333             0.545455
# 7              0.222222           0.000000             0.388889
# 8              0.083333           0.000000             0.500000
#
#     4_reviews_opposed  total_opp  total_supp  Reliability  NonReliability  \
# id
# 0            0.250000        0.0         0.0           15               2
# 4            0.500000        2.0         3.0           30               8
# 6            0.416667       12.0        66.0           80              10
# 7            0.666667        3.0        18.0           69              32
# 8            0.416667        0.0        12.0           65              72
#
#     Reliability_factor
# id
# 0             0.882353
# 4             0.789474
# 6             0.888889
# 7             0.683168
# 8             0.474453
#
# [5 rows x 25 columns]

# %%
X = train.drop('left', axis=1) 
y = train['left']

# %%
np.unique(y.values, return_counts=True)
# Out:
# (array([0, 1], dtype=int64), array([2932,  581], dtype=int64))

# %% [markdown]
# #### Due to the presence of class imbalance, negative sampling is done

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

train_data = pd.DataFrame.copy(X_train)
train_data['left']  = y_train

# %%
# Over Sampling Negative Class

pos_class = train_data[train_data['left']==1]
neg_class = train_data[train_data['left']==0]
neg_resampled = neg_class.sample(n=int(len(pos_class)), replace=False)
    
train_data_resampled = pd.concat([pos_class, neg_resampled])

# Use these for train_dataings

X_train_resampled = train_data_resampled.drop('left', axis=1).values
y_train_resampled = train_data_resampled['left']

# %%
train_data_resampled.columns
# Out:
# Index(['comp', 'Reused_id', '1_ratings', '2_ratings', '3_ratings', '4_ratings',
#        'total_num_ratings', 'lastrating', 'Delta_days', 'Supported', 'Opposed',
#        '1_reviews_supported', '1_reviews_opposed', '2_reviews_supported',
#        '2_reviews_opposed', '3_reviews_supported', '3_reviews_opposed',
#        '4_reviews_supported', '4_reviews_opposed', 'total_opp', 'total_supp',
#        'Reliability', 'NonReliability', 'Reliability_factor', 'left'],
#       dtype='object')

# %% [markdown]
# ### GridSearch CV

# %%
model = lgb.LGBMClassifier()
param_grid = {
    'n_estimators': [100, 500],
#     'max_depth': [15,20,25, -1],
    'num_leaves': [30, 50, 100],
    'reg_alpha': [1, 10, 20],
    'reg_lambda': [1, 10, 20],
    'feature_fraction': [0.5, 0.6, 0.7, 0.8],
    'bagging_fraction': [0.8, 0.9, 1],
    'subsample_freq': [10, 20, 50],
    'metric': ['auc']
}



cv = 5

gs = GridSearchCV(estimator=model,
        param_grid=param_grid, 
        cv=cv, 
        n_jobs=-1, 
        scoring='balanced_accuracy',
        verbose=2)
gs.fit(X_train_resampled, y_train_resampled)
# Out:
# Fitting 5 folds for each of 1944 candidates, totalling 9720 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done 264 tasks      | elapsed:    6.3s
# [Parallel(n_jobs=-1)]: Done 808 tasks      | elapsed:   15.8s
# [Parallel(n_jobs=-1)]: Done 1493 tasks      | elapsed:   26.2s
# [Parallel(n_jobs=-1)]: Done 1971 tasks      | elapsed:   34.2s
# [Parallel(n_jobs=-1)]: Done 2480 tasks      | elapsed:   49.9s
# [Parallel(n_jobs=-1)]: Done 3185 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 3991 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 4859 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 5841 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 7048 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 8175 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 9543 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=-1)]: Done 9720 out of 9720 | elapsed:  3.5min finished
# GridSearchCV(cv=5, error_score='raise-deprecating',
#              estimator=LGBMClassifier(boosting_type='gbdt', class_weight=None,
#                                       colsample_bytree=1.0,
#                                       importance_type='split',
#                                       learning_rate=0.1, max_depth=-1,
#                                       min_child_samples=20,
#                                       min_child_weight=0.001,
#                                       min_split_gain=0.0, n_estimators=100,
#                                       n_jobs=-1, num_leaves=31, objective=None,
#                                       random_state=None, reg_alpha=0.0,
#                                       reg_lambd...
#                                       subsample_freq=0),
#              iid='warn', n_jobs=-1,
#              param_grid={'bagging_fraction': [0.8, 0.9, 1],
#                          'feature_fraction': [0.5, 0.6, 0.7, 0.8],
#                          'metric': ['auc'], 'n_estimators': [100, 500],
#                          'num_leaves': [30, 50, 100], 'reg_alpha': [1, 10, 20],
#                          'reg_lambda': [1, 10, 20],
#                          'subsample_freq': [10, 20, 50]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='balanced_accuracy', verbose=2)

# %%
LGB_models2 = pd.DataFrame(gs.cv_results_)
best_LGB_model2 = LGB_models2.sort_values(by='mean_test_score', ascending=False).iloc[:5]

best_LGB_model2.loc[:, ['params', 'mean_test_score']]
# Out:
#                                                 params  mean_test_score
# 850  {'bagging_fraction': 0.9, 'feature_fraction': ...         0.858650
# 877  {'bagging_fraction': 0.9, 'feature_fraction': ...         0.858650
# 823  {'bagging_fraction': 0.9, 'feature_fraction': ...         0.858650
# 39   {'bagging_fraction': 0.8, 'feature_fraction': ...         0.857595
# 66   {'bagging_fraction': 0.8, 'feature_fraction': ...         0.857595

# %%
best_LGB_model2['params'].iloc[0]
# Out:
# {'bagging_fraction': 0.9,
#  'feature_fraction': 0.6,
#  'metric': 'auc',
#  'n_estimators': 100,
#  'num_leaves': 50,
#  'reg_alpha': 10,
#  'reg_lambda': 10,
#  'subsample_freq': 20}

# %%
LGB_models1 = pd.DataFrame(gs.cv_results_)
best_LGB_model1 = LGB_models1.sort_values(by='mean_test_score', ascending=False).iloc[:5]

best_LGB_model1.loc[:, ['params', 'mean_test_score']]
# Out:
#                                                  params  mean_test_score
# 7801  {'bagging_fraction': 0.9, 'feature_fraction': ...          0.85865
# 8071  {'bagging_fraction': 0.9, 'feature_fraction': ...          0.85865
# 8341  {'bagging_fraction': 0.9, 'feature_fraction': ...          0.85865
# 7828  {'bagging_fraction': 0.9, 'feature_fraction': ...          0.85865
# 8530  {'bagging_fraction': 0.9, 'feature_fraction': ...          0.85865

# %%
best_LGB_model1['params'].iloc[0]
# Out:
# {'bagging_fraction': 0.9,
#  'feature_fraction': 0.6,
#  'max_depth': 15,
#  'metric': 'auc',
#  'n_estimators': 100,
#  'num_leaves': 50,
#  'reg_alpha': 10,
#  'reg_lambda': 10,
#  'subsample_freq': 20}

# %%
best_LGB_model1['params'].iloc[4]
# Out:
# {'bagging_fraction': 0.9,
#  'feature_fraction': 0.6,
#  'max_depth': -1,
#  'metric': 'auc',
#  'n_estimators': 100,
#  'num_leaves': 50,
#  'reg_alpha': 10,
#  'reg_lambda': 10,
#  'subsample_freq': 20}

# %%
# LGB_models = pd.DataFrame(gs.cv_results_)
# best_LGB_model = LGB_models.sort_values(by='mean_test_score', ascending=False).iloc[:5]

# best_LGB_model.loc[:, ['params', 'mean_test_score']]
# Out:
#                                                  params  mean_test_score
# 2235  {'colsample_bytree': 0.8, 'max_depth': 20, 'me...         0.853376
# 2009  {'colsample_bytree': 0.8, 'max_depth': 20, 'me...         0.853376
# 1658  {'colsample_bytree': 0.8, 'max_depth': 15, 'me...         0.853376
# 2441  {'colsample_bytree': 0.8, 'max_depth': 25, 'me...         0.853376
# 2883  {'colsample_bytree': 0.8, 'max_depth': 25, 'me...         0.853376

# %%
best_LGB_model['params'].iloc[2]
# Out:
# {'colsample_bytree': 0.8,
#  'max_depth': 15,
#  'metric': 'auc',
#  'min_split_gain': 0.3,
#  'n_estimators': 1000,
#  'num_leaves': 100,
#  'reg_alpha': 1.2,
#  'reg_lambda': 1.1,
#  'subsample': 0.9,
#  'subsample_freq': 20}

# %% [markdown]
# Notes :
# 1. Try bagging of models? (mean probability and then classify)

# %% [markdown]
# ### Day 2 params - with bagging

# %%
n_models = 50

# %%
cv_params = {
    
    'objective': 'binary',   # 'cross_entropy',
#     'n_estimators': 1000,     # 100
#     'learning_rate':  0.01,   # 0.1
#     'num_leaves' : 31,        # 31
    'num_threads' : -1, 
    
    'max_depth': -1,          #-1 (no limit)
 
    'feature_fraction': 0.6,  # 1
    'bagging_fraction': 0.8,  # 1
    'reg_lambda': 10,

    'metric': 'auc',     
    }

models = []
y_train_preds = []
y_test_preds = []

for i in range(n_models):
    
    # Over Sampling Negative Class
    pos_class = train_data[train_data['left']==1]
    neg_class = train_data[train_data['left']==0]
    neg_resampled = neg_class.sample(n=int(len(pos_class)), replace=False)

    train_data_resampled = pd.concat([pos_class, neg_resampled])

    # Use these for train_dataings
    X_train_resampled = train_data_resampled.drop('left', axis=1).values
    y_train_resampled = train_data_resampled['left']    
        
    lgb_train = lgb.Dataset(X_train_resampled, y_train_resampled)

    model = lgb.train(cv_params, lgb_train,)

    y_train_prob = model.predict(X_train_resampled)
    y_test_prob = model.predict(X_test)

    models.append(model)
    y_train_preds.append(y_train_prob)
    y_test_preds.append(y_test_prob)
    
    thres = 0.5
    y_pred_train = np.zeros(len(y_train_prob))
    y_pred_train[np.argwhere(y_train_prob>thres)] = 1
    y_pred_test = np.zeros(len(y_test_prob))
    y_pred_test[np.argwhere(y_test_prob>thres)] = 1

    
    print('\n Model : ', i)
    print('Train Accuracy =', accuracy_score(y_train_resampled, y_pred_train))
    print('Train Balanced Accuracy =', balanced_accuracy_score(y_train_resampled, y_pred_train))
    print('Train F1 Score =', f1_score(y_train_resampled, y_pred_train))

    print('\n')

    print('Test Accuracy =', accuracy_score(y_test, y_pred_test))
    print('Test Balanced Accuracy =', balanced_accuracy_score(y_test, y_pred_test))
    print('Test F1 Score =', f1_score(y_test, y_pred_test))
# Out:
#  Model :  0
# Train Accuracy = 0.9630801687763713
# Train Balanced Accuracy = 0.9630801687763713
# Train F1 Score = 0.9631966351209252
#
#
# Test Accuracy = 0.8605974395448079
# Test Balanced Accuracy = 0.8679436116163833
# Test F1 Score = 0.6573426573426573
#
#  Model :  1
# Train Accuracy = 0.9588607594936709
# Train Balanced Accuracy = 0.9588607594936709
# Train F1 Score = 0.9591623036649215
#
#
# Test Accuracy = 0.8805120910384068
# Test Balanced Accuracy = 0.8796885780593364
# Test F1 Score = 0.6911764705882354
#
#  Model :  2
# Train Accuracy = 0.9630801687763713
# Train Balanced Accuracy = 0.9630801687763713
# Train F1 Score = 0.9635796045785641
#
#
# Test Accuracy = 0.8534850640113798
# Test Balanced Accuracy = 0.8599150097221351
# Test F1 Score = 0.643598615916955
#
#  Model :  3
# Train Accuracy = 0.9462025316455697
# Train Balanced Accuracy = 0.9462025316455696
# Train F1 Score = 0.9465968586387434
#
#
# Test Accuracy = 0.8662873399715505
# Test Balanced Accuracy = 0.8597974032490748
# Test F1 Score = 0.6594202898550725
#
#  Model :  4
# Train Accuracy = 0.9578059071729957
# Train Balanced Accuracy = 0.9578059071729959
# Train F1 Score = 0.9578947368421052
#
#
# Test Accuracy = 0.8691322901849218
# Test Balanced Accuracy = 0.8538073135545381
# Test F1 Score = 0.6592592592592592
#
#  Model :  5
# Train Accuracy = 0.9662447257383966
# Train Balanced Accuracy = 0.9662447257383966
# Train F1 Score = 0.9663157894736842
#
#
# Test Accuracy = 0.8819345661450925
# Test Balanced Accuracy = 0.880527504233833
# Test F1 Score = 0.6937269372693727
#
#  Model :  6
# Train Accuracy = 0.9704641350210971
# Train Balanced Accuracy = 0.9704641350210971
# Train F1 Score = 0.9705263157894737
#
#
# Test Accuracy = 0.8677098150782361
# Test Balanced Accuracy = 0.8683042714671015
# Test F1 Score = 0.6666666666666667
#
#  Model :  7
# Train Accuracy = 0.9567510548523207
# Train Balanced Accuracy = 0.9567510548523206
# Train F1 Score = 0.9571577847439916
#
#
# Test Accuracy = 0.8605974395448079
# Test Balanced Accuracy = 0.8602756695728533
# Test F1 Score = 0.652482269503546
#
#  Model :  8
# Train Accuracy = 0.9662447257383966
# Train Balanced Accuracy = 0.9662447257383966
# Train F1 Score = 0.9663157894736842
#
#
# Test Accuracy = 0.8620199146514936
# Test Balanced Accuracy = 0.86878253779088
# Test F1 Score = 0.6596491228070175
#
#  Model :  9
# Train Accuracy = 0.9567510548523207
# Train Balanced Accuracy = 0.9567510548523207
# Train F1 Score = 0.9572471324296141
#
#
# Test Accuracy = 0.8591749644381224
# Test Balanced Accuracy = 0.8594367433983566
# Test F1 Score = 0.6501766784452297
#
#  Model :  10
# Train Accuracy = 0.9609704641350211
# Train Balanced Accuracy = 0.9609704641350211
# Train F1 Score = 0.961093585699264
#
#
# Test Accuracy = 0.8819345661450925
# Test Balanced Accuracy = 0.876693533212068
# Test F1 Score = 0.691449814126394
#
#  Model :  11
# Train Accuracy = 0.9609704641350211
# Train Balanced Accuracy = 0.9609704641350212
# Train F1 Score = 0.9613375130616509
#
#
# Test Accuracy = 0.8648648648648649
# Test Balanced Accuracy = 0.8627924480963431
# Test F1 Score = 0.6594982078853047
#
#  Model :  12
# Train Accuracy = 0.9556962025316456
# Train Balanced Accuracy = 0.9556962025316456
# Train F1 Score = 0.9564315352697095
#
#
# Test Accuracy = 0.8591749644381224
# Test Balanced Accuracy = 0.8671046854418867
# Test F1 Score = 0.6550522648083623
#
#  Model :  13
# Train Accuracy = 0.9588607594936709
# Train Balanced Accuracy = 0.9588607594936709
# Train F1 Score = 0.9591623036649215
#
#
# Test Accuracy = 0.8705547652916074
# Test Balanced Accuracy = 0.8699821238160949
# Test F1 Score = 0.6714801444043321
#
#  Model :  14
# Train Accuracy = 0.9609704641350211
# Train Balanced Accuracy = 0.9609704641350211
# Train F1 Score = 0.9611752360965373
#
#
# Test Accuracy = 0.8691322901849218
# Test Balanced Accuracy = 0.8729771686633632
# Test F1 Score = 0.6714285714285714
#
#  Model :  15
# Train Accuracy = 0.9525316455696202
# Train Balanced Accuracy = 0.9525316455696202
# Train F1 Score = 0.9527806925498425
#
#
# Test Accuracy = 0.8677098150782361
# Test Balanced Accuracy = 0.8683042714671015
# Test F1 Score = 0.6666666666666667
#
#  Model :  16
# Train Accuracy = 0.9546413502109705
# Train Balanced Accuracy = 0.9546413502109705
# Train F1 Score = 0.955067920585162
#
#
# Test Accuracy = 0.8591749644381224
# Test Balanced Accuracy = 0.8747726274854168
# Test F1 Score = 0.6597938144329897
#
#  Model :  17
# Train Accuracy = 0.9683544303797469
# Train Balanced Accuracy = 0.9683544303797469
# Train F1 Score = 0.9684873949579833
#
#
# Test Accuracy = 0.8520625889046942
# Test Balanced Accuracy = 0.8590760835476385
# Test F1 Score = 0.6413793103448275
#
#  Model :  18
# Train Accuracy = 0.9535864978902954
# Train Balanced Accuracy = 0.9535864978902954
# Train F1 Score = 0.9538784067085954
#
#
# Test Accuracy = 0.8577524893314367
# Test Balanced Accuracy = 0.8700997302891551
# Test F1 Score = 0.6551724137931034
#
#  Model :  19
# Train Accuracy = 0.9672995780590717
# Train Balanced Accuracy = 0.9672995780590717
# Train F1 Score = 0.9674027339642483
#
#
# Test Accuracy = 0.8634423897581792
# Test Balanced Accuracy = 0.8657874929436116
# Test F1 Score = 0.6595744680851064
#
#  Model :  20
# Train Accuracy = 0.9556962025316456
# Train Balanced Accuracy = 0.9556962025316456
# Train F1 Score = 0.9560669456066946
#
#
# Test Accuracy = 0.871977240398293
# Test Balanced Accuracy = 0.8708210499905915
# Test F1 Score = 0.6739130434782609
#
#  Model :  21
# Train Accuracy = 0.9567510548523207
# Train Balanced Accuracy = 0.9567510548523206
# Train F1 Score = 0.9571577847439916
#
#
# Test Accuracy = 0.871977240398293
# Test Balanced Accuracy = 0.8861569340776516
# Test F1 Score = 0.6830985915492958
#
#  Model :  22
# Train Accuracy = 0.959915611814346
# Train Balanced Accuracy = 0.9599156118143459
# Train F1 Score = 0.9603340292275575
#
#
# Test Accuracy = 0.8605974395448079
# Test Balanced Accuracy = 0.8641096405946183
# Test F1 Score = 0.6549295774647887
#
#  Model :  23
# Train Accuracy = 0.9641350210970464
# Train Balanced Accuracy = 0.9641350210970464
# Train F1 Score = 0.9643605870020965
#
#
# Test Accuracy = 0.8634423897581792
# Test Balanced Accuracy = 0.8734554349871417
# Test F1 Score = 0.6643356643356644
#
#  Model :  24
# Train Accuracy = 0.9409282700421941
# Train Balanced Accuracy = 0.9409282700421941
# Train F1 Score = 0.9419087136929459
#
#
# Test Accuracy = 0.8748221906116643
# Test Balanced Accuracy = 0.8724989023395848
# Test F1 Score = 0.6788321167883211
#
#  Model :  25
# Train Accuracy = 0.9588607594936709
# Train Balanced Accuracy = 0.9588607594936709
# Train F1 Score = 0.9589041095890412
#
#
# Test Accuracy = 0.8847795163584637
# Test Balanced Accuracy = 0.8822053565828263
# Test F1 Score = 0.6988847583643123
#
#  Model :  26
# Train Accuracy = 0.9651898734177216
# Train Balanced Accuracy = 0.9651898734177216
# Train F1 Score = 0.9655891553701773
#
#
# Test Accuracy = 0.8762446657183499
# Test Balanced Accuracy = 0.8656698864705513
# Test F1 Score = 0.6765799256505577
#
#  Model :  27
# Train Accuracy = 0.9609704641350211
# Train Balanced Accuracy = 0.9609704641350212
# Train F1 Score = 0.9612565445026178
#
#
# Test Accuracy = 0.8705547652916074
# Test Balanced Accuracy = 0.8776500658596249
# Test F1 Score = 0.6761565836298933
#
#  Model :  28
# Train Accuracy = 0.9620253164556962
# Train Balanced Accuracy = 0.9620253164556962
# Train F1 Score = 0.9623430962343097
#
#
# Test Accuracy = 0.8648648648648649
# Test Balanced Accuracy = 0.8742943611616383
# Test F1 Score = 0.6666666666666667
#
#  Model :  29
# Train Accuracy = 0.9609704641350211
# Train Balanced Accuracy = 0.9609704641350211
# Train F1 Score = 0.9611752360965373
#
#
# Test Accuracy = 0.8662873399715505
# Test Balanced Accuracy = 0.8636313742708399
# Test F1 Score = 0.6618705035971223
#
#  Model :  30
# Train Accuracy = 0.9567510548523207
# Train Balanced Accuracy = 0.9567510548523207
# Train F1 Score = 0.9572471324296141
#
#
# Test Accuracy = 0.8605974395448079
# Test Balanced Accuracy = 0.8794455246816785
# Test F1 Score = 0.6643835616438356
#
#  Model :  31
# Train Accuracy = 0.9578059071729957
# Train Balanced Accuracy = 0.9578059071729959
# Train F1 Score = 0.9580712788259957
#
#
# Test Accuracy = 0.8534850640113798
# Test Balanced Accuracy = 0.8637489807439002
# Test F1 Score = 0.6460481099656358
#
#  Model :  32
# Train Accuracy = 0.959915611814346
# Train Balanced Accuracy = 0.9599156118143459
# Train F1 Score = 0.9603340292275575
#
#
# Test Accuracy = 0.8620199146514936
# Test Balanced Accuracy = 0.872616508812645
# Test F1 Score = 0.6620209059233451
#
#  Model :  33
# Train Accuracy = 0.9535864978902954
# Train Balanced Accuracy = 0.9535864978902954
# Train F1 Score = 0.9541666666666667
#
#
# Test Accuracy = 0.8634423897581792
# Test Balanced Accuracy = 0.8734554349871417
# Test F1 Score = 0.6643356643356644
#  Model :  34
# Train Accuracy = 0.9567510548523207
# Train Balanced Accuracy = 0.9567510548523207
# Train F1 Score = 0.956887486855941
#
#
# Test Accuracy = 0.8705547652916074
# Test Balanced Accuracy = 0.8661481527943298
# Test F1 Score = 0.6690909090909092
#
#  Model :  35
# Train Accuracy = 0.9567510548523207
# Train Balanced Accuracy = 0.9567510548523207
# Train F1 Score = 0.956887486855941
#
#
# Test Accuracy = 0.8605974395448079
# Test Balanced Accuracy = 0.8641096405946183
# Test F1 Score = 0.6549295774647887
#
#  Model :  36
# Train Accuracy = 0.9588607594936709
# Train Balanced Accuracy = 0.9588607594936709
# Train F1 Score = 0.9590766002098636
#
#
# Test Accuracy = 0.8549075391180654
# Test Balanced Accuracy = 0.8530859938531017
# Test F1 Score = 0.6408450704225352
#
#  Model :  37
# Train Accuracy = 0.959915611814346
# Train Balanced Accuracy = 0.9599156118143459
# Train F1 Score = 0.9603340292275575
#
#
# Test Accuracy = 0.8677098150782361
# Test Balanced Accuracy = 0.8683042714671015
# Test F1 Score = 0.6666666666666667
#
#  Model :  38
# Train Accuracy = 0.9483122362869199
# Train Balanced Accuracy = 0.9483122362869199
# Train F1 Score = 0.948905109489051
#
#
# Test Accuracy = 0.8762446657183499
# Test Balanced Accuracy = 0.8695038574923164
# Test F1 Score = 0.6789667896678966
#
#  Model :  39
# Train Accuracy = 0.9588607594936709
# Train Balanced Accuracy = 0.9588607594936709
# Train F1 Score = 0.9589905362776026
#
#
# Test Accuracy = 0.8662873399715505
# Test Balanced Accuracy = 0.8789672583579
# Test F1 Score = 0.6713286713286714
#
#  Model :  40
# Train Accuracy = 0.9556962025316456
# Train Balanced Accuracy = 0.9556962025316456
# Train F1 Score = 0.9558823529411765
#
#
# Test Accuracy = 0.8634423897581792
# Test Balanced Accuracy = 0.8696214639653767
# Test F1 Score = 0.6619718309859154
#
#  Model :  41
# Train Accuracy = 0.9493670886075949
# Train Balanced Accuracy = 0.9493670886075949
# Train F1 Score = 0.9497907949790796
#
#
# Test Accuracy = 0.871977240398293
# Test Balanced Accuracy = 0.8631531079470613
# Test F1 Score = 0.6691176470588235
#
#  Model :  42
# Train Accuracy = 0.9546413502109705
# Train Balanced Accuracy = 0.9546413502109705
# Train F1 Score = 0.9544973544973545
#
#
# Test Accuracy = 0.8790896159317212
# Test Balanced Accuracy = 0.8750156808630747
# Test F1 Score = 0.6863468634686346
#
#  Model :  43
# Train Accuracy = 0.9472573839662447
# Train Balanced Accuracy = 0.9472573839662448
# Train F1 Score = 0.9479166666666669
#
#
# Test Accuracy = 0.8648648648648649
# Test Balanced Accuracy = 0.8627924480963431
# Test F1 Score = 0.6594982078853047
#
#  Model :  44
# Train Accuracy = 0.9525316455696202
# Train Balanced Accuracy = 0.9525316455696202
# Train F1 Score = 0.9526813880126183
#
#
# Test Accuracy = 0.8748221906116643
# Test Balanced Accuracy = 0.8763328733613498
# Test F1 Score = 0.681159420289855
#
#  Model :  45
# Train Accuracy = 0.9567510548523207
# Train Balanced Accuracy = 0.9567510548523206
# Train F1 Score = 0.9567053854276663
#
#
# Test Accuracy = 0.8691322901849218
# Test Balanced Accuracy = 0.8653092266198332
# Test F1 Score = 0.6666666666666667
#
#  Model :  46
# Train Accuracy = 0.9588607594936709
# Train Balanced Accuracy = 0.9588607594936709
# Train F1 Score = 0.958817317845829
#
#
# Test Accuracy = 0.8648648648648649
# Test Balanced Accuracy = 0.8742943611616383
# Test F1 Score = 0.6666666666666667
#
#  Model :  47
# Train Accuracy = 0.9641350210970464
# Train Balanced Accuracy = 0.9641350210970464
# Train F1 Score = 0.9642105263157894
#
#
# Test Accuracy = 0.8691322901849218
# Test Balanced Accuracy = 0.8653092266198332
# Test F1 Score = 0.6666666666666667
#
#  Model :  48
# Train Accuracy = 0.9514767932489452
# Train Balanced Accuracy = 0.9514767932489452
# Train F1 Score = 0.9517819706498951
#
#
# Test Accuracy = 0.8591749644381224
# Test Balanced Accuracy = 0.8632707144201217
# Test F1 Score = 0.6526315789473685
#
#  Model :  49
# Train Accuracy = 0.959915611814346
# Train Balanced Accuracy = 0.9599156118143459
# Train F1 Score = 0.9601677148846961
#
#
# Test Accuracy = 0.8634423897581792
# Test Balanced Accuracy = 0.8734554349871417
# Test F1 Score = 0.6643356643356644

# %%
y_test_preds = np.array(y_test_preds)

# %%
y_test_prob_final = np.mean(y_test_preds, axis=0)


thres = 0.5

y_pred_test_final = np.zeros(len(y_test_prob_final))
y_pred_test_final[np.argwhere(y_test_prob_final>thres)] = 1


print('Test Accuracy =', accuracy_score(y_test, y_pred_test_final))
print('Test Balanced Accuracy =', balanced_accuracy_score(y_test, y_pred_test_final))
print('Test F1 Score =', f1_score(y_test, y_pred_test_final))
# Out:
# Test Accuracy = 0.8648648648648649
# Test Balanced Accuracy = 0.8627924480963431
# Test F1 Score = 0.6594982078853047

# %% [markdown]
# ### Training

# %%
# Over Sampling Negative Class

pos_class = train[train['left']==1]
neg_class = train[train['left']==0]
neg_resampled = neg_class.sample(n=int(len(pos_class)), replace=False)
    
train_resampled = pd.concat([pos_class, neg_resampled])

# Use these for trainings

X_train_resampled = train_resampled.drop('left', axis=1).values
y_train_resampled = train_resampled['left']

# %%
X_test = test.values

# %%
# cv_params = {
#     'max_depth': -1,
#     'objective': 'binary',
#     'metric':'auc',  
#     'feature_fraction': 0.6, 
#     'bagging_fraction': 0.8,
#     'reg_lambda': 10,
#     'n_estimators':1000
    
#     }

# cv_params = {
    
#     'objective': 'binary',   # 'cross_entropy',
# #     'n_estimators': 1000,     # 100
# #     'learning_rate':  0.01,   # 0.1
# #     'num_leaves' : 31,        # 31
#     'num_threads' : -1, 
    
#     'max_depth': -1,          #-1 (no limit)
    
 
#     'feature_fraction': 0.6,  # 1
#     'bagging_fraction': 0.8,  # 1
#     'reg_lambda': 10,

    
#     'metric': 'auc',     
#     }

cv_params = {'bagging_fraction': 0.9,
 'feature_fraction': 0.6,
 'metric': 'auc',
 'n_estimators': 100,
 'num_leaves': 50,
 'reg_alpha': 10,
 'reg_lambda': 10,
 'subsample_freq': 20}


lgb_train = lgb.Dataset(X_train_resampled, y_train_resampled)

model = lgb.train(cv_params, 
                lgb_train, 
                verbose_eval=1)

y_train_prob = model.predict(X_train_resampled)
y_test_prob = model.predict(X_test)

     
thres = 0.5
y_pred_train = np.zeros(len(y_train_prob))
y_pred_train[np.argwhere(y_train_prob>thres)] = 1
y_pred_test = np.zeros(len(y_test_prob))
y_pred_test[np.argwhere(y_test_prob>thres)] = 1
     
print('Train Accuracy =', accuracy_score(y_train_resampled, y_pred_train))
print('Train Balanced Accuracy =', balanced_accuracy_score(y_train_resampled, y_pred_train))
print('Train F1 Score =', f1_score(y_train_resampled, y_pred_train))

# print('\n\n')

# print('Test Accuracy =', accuracy_score(y_test, y_pred_test))
# print('Test Balanced Accuracy =', balanced_accuracy_score(y_test, y_pred_test))
# print('Test F1 Score =', f1_score(y_test, y_pred_test))
# Out:
# Train Accuracy = 0.9561101549053356
# Train Balanced Accuracy = 0.9561101549053357
# Train F1 Score = 0.9565957446808512

# %%
predictions = pd.DataFrame({'left':y_pred_test.astype(int)}, index=test.index)

# %%
baseline = pd.read_csv('Dataset/baseline_0.csv')

# %%
predictions_ord = predictions.loc[baseline['id'].values, :]

# %%
# Change this: format _day<no.>_<attempt no.>

# predictions_ord.to_csv('predictions_lgb_day2.csv')
